# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\Rashmi\Desktop\Nilesh classes\Test dataset\amazon-fine-food-reviews\Reviews.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
# Id                        568454 non-null int64
# ProductId                 568454 non-null object
# UserId                    568454 non-null object
# ProfileName               568438 non-null object
# HelpfulnessNumerator      568454 non-null int64
# HelpfulnessDenominator    568454 non-null int64
# Score                     568454 non-null int64
# Time                      568454 non-null int64
# Summary                   568427 non-null object
# Text                      568454 non-null object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
data.isna().sum()

# %%
Null_value
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
data.shape
# Out:
# (568454, 10)

# %%
data.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
data1=data.copy()

# %%
data1[data1.isna().any(axis=1)]
# Out:
#             Id   ProductId          UserId                     ProfileName  \
# 25509    25510  B000LKZB4Y  A36BVYD0NT7Z0F                             NaN
# 33958    33959  B00412W76S  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 38874    38875  B000AYDGZ2  A36BVYD0NT7Z0F                             NaN
# 40548    40549  B00020HHRW  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 49800    49801  B000CRHQN0  A2LYFY32LXQDON                             NaN
# 67077    67078  B0006348H2  A2P0P67Y55SNOX                             NaN
# 101106  101107  B0014B0HWK  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 102979  102980  B000FVDWU4  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 106550  106551  B001EQ5DG0  A1P500QXEG3IUZ                             NaN
# 117515  117516  B0016B7Z32  A3TJPSWY2HE4BS  S. Layton "homeschool blogger"
# 137613  137614  B000CQE3HS   AGT3BYX5P9SLH                             NaN
# ...

# %%
data1.dropna(axis='index',inplace=True)

# %%
data1.isna().sum()
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# Text                      0
# dtype: int64

# %%
data2=data.copy()

# %%
data2.dropna(axis='index',inplace=False).shape
# Out:
# (568411, 10)

# %%
data2.shape
# Out:
# (568454, 10)

# %%
data.isna().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
data1.shape
# Out:
# (568454, 8)

# %%
data1.shape
# Out:
# (568454, 10)

# %%
#np.unique(data1['ProfileName'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-091963c1c459> in <module>
# ----> 1 np.unique(data1['ProfileName'])
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     262     ar = np.asanyarray(ar)
#     263     if axis is None:
# --> 264         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     265         return _unpack_tuple(ret)
#     266
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     310         aux = ar[perm]
#     311     else:
# --> 312         ar.sort()
#     313         aux = ar
#     314     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 568424    False
# 568425    False
# 568426    False
# 568427    False
# 568428    False
# 568429    False
# 568430    False
# 568431    False
# 568432    False
# 568433    False
# 568434    False
# 568435    False
# 568436    False
# 568437    False
# 568438    False
# 568439    False
# 568440    False
# 568441    False
# 568442    False
# 568443    False
# 568444    False
# 568445    False
# 568446    False
# 568447    False
# ...
